# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

#1. 열 이름이 잘 인식되었는지
df = pd.read_csv("C:\\Users\\user\\2024_ai_test\\data\\PAMAP_features.csv", index_col=0)#따로 넣을거면 names=[] 없다면 header=None
df
# Out:
#        sub_id  activity_id act_level     hr_mean  hr_mean_normal    hr_std  \
# 3006        2           17     light   87.000000        1.175676  0.000000
# 3497        2            4  moderate  124.605469        1.683858  0.927920
# 14495       7            5  vigorous  113.493430        1.891557  2.315888
# 13278       7           17     light   82.513672        1.375228  0.492657
# 14969       8            3     light   73.000000        1.106061  0.000000
# ...       ...          ...       ...         ...             ...       ...
# 10708       6            2     light   82.582031        1.376367  0.930285
# 4870        3            2     light   76.998047        1.132324  0.806906
# 11822       6            4  moderate   93.445312        1.557422  0.493415
# 3866        2            7  moderate  129.160156        1.745408  0.361877
# 3450        2           13  moderate  142.234375        1.922086  1.714464
#
# ...

# %%
#2. 열 이름 확인
df.columns
# Out:
# Index(['sub_id', 'activity_id', 'act_level', 'hr_mean', 'hr_mean_normal',
#        'hr_std', 'hr_std_normal', 'hand_tmp_mean', 'hand_tmp_std',
#        'hand_acc_x_mean', 'hand_acc_x_std', 'hand_acc_y_mean',
#        'hand_acc_y_std', 'hand_acc_z_mean', 'hand_acc_z_std',
#        'hand_gyr_x_mean', 'hand_gyr_x_std', 'hand_gyr_y_mean',
#        'hand_gyr_y_std', 'hand_gyr_z_mean', 'hand_gyr_z_std', 'chest_tmp_mean',
#        'chest_tmp_std', 'chest_acc_x_mean', 'chest_acc_x_std',
#        'chest_acc_y_mean', 'chest_acc_y_std', 'chest_acc_z_mean',
#        'chest_acc_z_std', 'chest_gyr_x_mean', 'chest_gyr_x_std',
#        'chest_gyr_y_mean', 'chest_gyr_y_std', 'chest_gyr_z_mean',
#        'chest_gyr_z_std', 'ankle_tmp_mean', 'ankle_tmp_std',
#        'ankle_acc_x_mean', 'ankle_acc_x_std', 'ankle_acc_y_mean',
#        'ankle_acc_y_std', 'ankle_acc_z_mean', 'ankle_acc_z_std',
#        'ankle_gyr_x_mean', 'ankle_gyr_x_std', 'ankle_gyr_y_mean',
# ...

# %%
#3. 객체 목록 확인
df['sub_id'].value_counts()
# Out:
# sub_id
# 5    1651
# 2    1618
# 8    1576
# 6    1556
# 1    1518
# 7    1430
# 4    1353
# 3    1042
# 9      29
# Name: count, dtype: int64

# %%
#4. 레이블 불균형 확인
df['act_level'].value_counts()
# Out:
# act_level
# moderate    5283
# light       5124
# vigorous    1366
# Name: count, dtype: int64

# %%
#5. 결측값 확인
df.isnull().sum()
# Out:
# sub_id              0
# activity_id         0
# act_level           0
# hr_mean             0
# hr_mean_normal      0
#                    ..
# chest_gyr_yz_cor    0
# chest_gyr_xz_cor    0
# ankle_gyr_xy_cor    0
# ankle_gyr_yz_cor    0
# ankle_gyr_xz_cor    0
# Length: 67, dtype: int64

# %%
#5-1. 결측값이 있다면
df['hr_mean'].fillna(df['hr_mean'].mean(), inplace=True)

# %%
#레이블 분리
y=df['act_level']
y.head()
# Out:
# 3006        light
# 3497     moderate
# 14495    vigorous
# 13278       light
# 14969       light
# Name: act_level, dtype: object

# %%
#데이터 분리
X=df.drop(['act_level', 'sub_id', 'activity_id'], axis=1)#x축 방향
X.head()
# Out:
#           hr_mean  hr_mean_normal    hr_std  hr_std_normal  hand_tmp_mean  \
# 3006    87.000000        1.175676  0.000000   7.105427e-15        34.3750
# 3497   124.605469        1.683858  0.927920   1.253946e-02        31.8750
# 14495  113.493430        1.891557  2.315888   3.859813e-02        32.5000
# 13278   82.513672        1.375228  0.492657   8.210948e-03        33.8125
# 14969   73.000000        1.106061  0.000000   7.327472e-15        34.4375
#
#        hand_tmp_std  hand_acc_x_mean  hand_acc_x_std  hand_acc_y_mean  \
# 3006            0.0        -1.165524        2.383779         3.381285
# 3497            0.0       -12.040995        3.734766         3.069947
# 14495           0.0        -3.723040       10.188184        11.705779
# 13278           0.0        -3.618932        1.935690         0.542981
# 14969           0.0        -9.275877        0.082824         1.006239
#
#        hand_acc_y_std  ...  ankle_acc_xz_cor  hand_gyr_xy_cor  \
# ...

# %%
#훈련 테스트 데이터 분리
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X,
                                                  y,
                                                  test_size=0.2,
                                                  shuffle=True,
                                                  random_state=12)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (9418, 64) (9418,)
# (2355, 64) (2355,)

# %%
#1. 로지스틱 회귀
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn import datasets, metrics
import warnings

model1 = LogisticRegression(random_state=0)
model1.fit(X_train, y_train)

pred1 = model1.predict(X_test)

print ("\n--- Logistic Regression Classifier ---")
print (accuracy_score(y_test, pred1))
print (confusion_matrix(y_test, pred1))
print(f"{metrics.classification_report(y_test, pred1)}\n")
# Out:
# --- Logistic Regression Classifier ---
# 0.9932059447983015
# [[1063    5    0]
#  [   6 1022    3]
#  [   0    2  254]]
#               precision    recall  f1-score   support
#
#        light       0.99      1.00      0.99      1068
#     moderate       0.99      0.99      0.99      1031
#     vigorous       0.99      0.99      0.99       256
#
#     accuracy                           0.99      2355
#    macro avg       0.99      0.99      0.99      2355
# weighted avg       0.99      0.99      0.99      2355
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
#2. 랜덤포레스트
print ("\n--- Radom Forest ---")
model2 = RandomForestClassifier(random_state=0)
model2.fit(X_train, y_train)
pred2 = model2.predict(X_test)
print(accuracy_score(y_test,pred2))
print (confusion_matrix(y_test, pred2))
print(f"{metrics.classification_report(y_test, pred2)}\n")
# Out:
# --- Radom Forest ---
# 0.9983014861995754
# [[1066    2    0]
#  [   2 1029    0]
#  [   0    0  256]]
#               precision    recall  f1-score   support
#
#        light       1.00      1.00      1.00      1068
#     moderate       1.00      1.00      1.00      1031
#     vigorous       1.00      1.00      1.00       256
#
#     accuracy                           1.00      2355
#    macro avg       1.00      1.00      1.00      2355
# weighted avg       1.00      1.00      1.00      2355

# %%
#3. 결정트리
model3 = DecisionTreeClassifier()
model3.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

pred3=model3.predict(X_test)
print(accuracy_score(y_test,pred3))
print (confusion_matrix(y_test, pred3))
print(f"{metrics.classification_report(y_test, pred3)}\n")
# Out:
# 0.9876857749469214
# [[1057   11    0]
#  [   9 1016    6]
#  [   0    3  253]]
#               precision    recall  f1-score   support
#
#        light       0.99      0.99      0.99      1068
#     moderate       0.99      0.99      0.99      1031
#     vigorous       0.98      0.99      0.98       256
#
#     accuracy                           0.99      2355
#    macro avg       0.98      0.99      0.99      2355
# weighted avg       0.99      0.99      0.99      2355
